# %%
my_list=[1,2,3,4]
my_list.append(5)
print (my_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list=[1,2,3,4]
my_list.remove(3)
print (my_list)
# Out:
# [1, 2, 4]

# %%
my_list=[1,2,3,4]
popped_item = my_list.pop()
print("popped_item is :" , popped_item)
print (my_list)
# Out:
# popped_item is : 4
# [1, 2, 3]

# %%
my_list=[1,2,3,4]
my_list.insert(1,10)
print (my_list)
# Out:
# [1, 10, 2, 3, 4]

# %%
my_list=[8,9,6,2,3,4]
my_list.sort()
print (my_list)
# Out:
# [2, 3, 4, 6, 8, 9]

# %%
my_list=[1,2,3,4]
my_list.reverse()
print (my_list)
# Out:
# [4, 3, 2, 1]

# %%
a = [10,20,30,40,50]
print(a[1:4]) # first index in inclusive and last one is exclusive
# Out:
# [20, 30, 40]

# %%
a = [10,20,30,40,50]
print(a[::3])
# Out:
# [10, 40]

# %%
a = [10,20,30,40,50]
print(a[:2])
# Out:
# [10, 20]

# %%
a = [10,20,30,40,50]
print(a[-2:])
# Out:
# [40, 50]

# %%
a = [10,20,30,40,50]
print(a[1:4:3])
# Out:
# [20]

# %%
a = [10,20,30,40,50]
print(a[-1::2])
# Out:
# [50]

# %%
A =[5,6,7,8,9,10]
print(A[-2::-2])
# Out:
# [9, 7, 5]

# %%
A =[5,6,7,8,9,10]
print(A[2::-2])
# Out:
# [7, 5]

# %% [markdown]
# # Tuples
#
# ## Ordered collection , immutable , faster than list, useful for fixed data

# %%
my_tuple = (10,20,30)
print(my_tuple[0])   
print(my_tuple[-1])  
print(my_tuple[1:3])
# Out:
# 10
# 30
# (20, 30)

# %%
import time

start = time.time()
for _ in range(5_555_000):
    a = [1,2,3,4]
end = time.time()
print("List creation :",end - start)
# Out:
# List creation : 0.4901092052459717

# %%
import time

start = time.time()
for _ in range(5_555_000):
    a = (1,2,3,4)
end = time.time()
print("Tuple creation :",end - start)
# Out:
# Tuple creation : 0.26067447662353516

# %%
import sys

a=[1,2,3,4,5]
b = (1,2,3,4,5)
print(sys.getsizeof(a))
print(sys.getsizeof(b))
# Out:
# 104
# 80

# %% [markdown]
# # set

# %%
s ={1,2,3,4,2}
print(s)
# Out:
# {1, 2, 3, 4}

# %%
A = {1,2,3,4}
B = {3,4,5,6}
print(A.symmetric_difference(B))
# Out:
# {1, 2, 5, 6}

# %%
A = {1,2,3,4}
B = {3,4,5,6}
print(A.union(B))
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A = {1,2,3,4}
B = {3,4,5,6}
print(A.intersection(B))
# Out:
# {3, 4}

# %%
A = {1,2,3,4}
B = {3,4,5,6}
print(A.difference(B))
# Out:
# {1, 2}

# %%
import time
nums_list = list(range(1_000-000))
nums_set =
# Out:
#   Cell In[28], line 3
#     nums_set =
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Dictionaries

# %% [markdown]
# ## key-value pairs ,mutable ,fast lookup

# %%
# synatx
student = {"name":"Alex", "age": 25 , "grade":'A'}
print(student["name"])
student["age"]=26
print(student["age"])
student["city"]="KATHMANDU"

student.keys()
# Out:
# Alex
# 26
# dict_keys(['name', 'age', 'grade', 'city'])

# %%
student = {"name":"Alex", "age": 25 , "grade":'A'}
print(student["name"])
student["age"]=26
print(student["age"])
student["city"]="KATHMANDU"

student.values()
# Out:
# Alex
# 26
# dict_values(['Alex', 26, 'A', 'KATHMANDU'])

# %%
student = {"name":"Alex", "age": 25 , "grade":'A'}
print(student["name"])
student["age"]=26
print(student["age"])
student["city"]="KATHMANDU"

student.items()
# Out:
# Alex
# 26
# dict_items([('name', 'Alex'), ('age', 26), ('grade', 'A'), ('city', 'KATHMANDU')])

# %%
student = {"name":"Alex", "age": 25 , "grade":'A'}
print(student["name"])
student["age"]=26
print(student["age"])
student["city"]="KATHMANDU"

student.get("grade")
# Out:
# Alex
# 26
# 'A'

# %%
student = {"name":"Alex", "age": 25 , "grade":'A'}
print(student["name"])
student["age"]=26
print(student["age"])
student["city"]="KATHMANDU"

student.pop("age")
# Out:
# Alex
# 26
# 26

# %%
student = {"name":"Alex", "age": 25 , "grade":'A'}
print(student["name"])
student["age"]=26
print(student["age"])
student["city"]="KATHMANDU"

print(student.keys())
print(student.values())
print(student.items())
print(student.get("grade"))
print(student.pop("age"))
# Out:
# Alex
# 26
# dict_keys(['name', 'age', 'grade', 'city'])
# dict_values(['Alex', 26, 'A', 'KATHMANDU'])
# dict_items([('name', 'Alex'), ('age', 26), ('grade', 'A'), ('city', 'KATHMANDU')])
# A
# 26

# %% [markdown]
# # strings
# ## sequence of chars,immutable,can be indexed/sliced

# %% [markdown]
# # array
# ## store elements of same type, more efficient than lists

# %%
from array import array
arr = array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
from array import array
arr = array('j',[1,2,3,4])
print(arr)

# why error when we put j
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 from array import array
# ----> 2 arr = array('j',[1,2,3,4])
#       3 print(arr)
#
# ValueError: bad typecode (must be b, B, u, w, h, H, i, I, l, L, q, Q, f or d)

# %% [markdown]
# # Arraymethods

# %%
from collections import Counter
c = Counter("banana")
print(c)

from collections import defaultdict
d = defaultdict(int)
d["a"] += 1
print(d)

from collections import namedtuple
Point = namedtuple("Point","x y")
p= Point(10,20)
print(p)
# Out:
# Counter({'a': 3, 'n': 2, 'b': 1})
# defaultdict(<class 'int'>, {'a': 1})
# Point(x=10, y=20)
# 10 20

# %% [markdown]
# # To REMEMBER
# # List: ordered , dynamic data
# # Tuple : ordered , fixed ,faster reads
# # Set : unique items + fast membership
# # Dict : key-value mapping ,fast lookup
# # Array : memory - efficient numeric storage
# # Deque :fast queue/stack opeartions
# # heap : priority-based smmalest/largest access
# # Counter : fast frequency counting
# # DefaultDict : grouping + auto-initialized dict

# %% [markdown]
# """
# Title
# Objective (3-4 points)
# Scope and Application (3-4 points)
# Introduction (800-1000 words, ~2 pages)
# Literature Review (aru le k gareko cha research)
# Methodology
#     - Dataset Collection
#     - EDA
# Conclusion
# """

# %%
# 
""" 
Title
Objective (3-4 points) 
Scope and Application (3-4 points) 
Introduction (800-1000 words, ~2 pages) 
Literature Review (aru le k gareko cha research  4-5 papers  ) 
 - Focus more on traditional ML methods
 - 
Methodology 
- Dataset Collection
- EDA 
Conclusion 
"""
#

# %%
x = sorted([-4,1,-2,3], key=abs,
reverse=True)
print (x)
# Out:
# [-4, 3, -2, 1]

# %%
squares = [x*x for x in range(1, 6)]
print(squares)
evens = [x for x in range(10) if x % 2 == 0]
print(evens)
# Out:
# [1, 4, 9, 16, 25]
# [0, 2, 4, 6, 8]

# %%
import random
print(random.randint(1, 6))
# Out:
# 2

# %%
from functools import reduce
nums = [1, 2, 3, 4]
total = reduce(lambda a, b: a + b, nums)
print(total)
# Out:
# 10

# %%
text = "dipti"
stack.append(text)

rev =""
while stack:
